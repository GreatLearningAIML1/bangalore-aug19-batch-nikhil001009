# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import cv2
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input

# %% [markdown]
# ### Change directory

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
codepath = "/content/drive/My Drive/Colab Notebooks"
import os
os.chdir(codepath)
# !pwd
# !ls -l
# Out:
# /content/drive/My Drive/Colab Notebooks
# total 1835411
# -rw------- 1 root root     18803 Sep 13 05:41  ACVILR9.ipynb
# -rw------- 1 root root    684858 Feb  9  2020  bank.csv
# -rw------- 1 root root 303646744 Apr  5 11:09  blog-authorship-corpus.zip
# -rw------- 1 root root   4821392 Feb 16  2020  bluelabel_cnn.h5
# -rw------- 1 root root     29864 Feb 29  2020 'CNN_Basics_MNIST (1).ipynb'
# -rw------- 1 root root   4821376 Feb 16  2020  cnn_mnist_weights.h5
# -rw------- 1 root root     92668 Jan 12  2020 'content based recommendation_detailed.ipynb'
# -rw------- 1 root root    108204 Feb  9  2020 'Copy of Introduction to NN_Project_ Resi_6_Solutions_KK_ver 5.ipynb'
# -rw------- 1 root root     55995 May 31 08:42  daily-minimum-temperatures-in-me.csv
# lrw------- 1 root root         0 Jun 14 15:35  Data -> /content/drive/.shortcut-targets-by-id/1s37-DVvRWfOcv59ojc6DnwHzPFkA6e8M/Data
# -rw------- 1 root root     32600 Feb 16  2020 'DataAugmentation (1).ipynb'
# -rw------- 1 root root    101891 Feb 16  2020  Deep_Learning_model_for_custom_image_dataset.ipynb
# -rw------- 1 root root     23394 Feb 16  2020  Deep_Learning_Model_MNIST_Data.ipynb
# -rw------- 1 root root   4319786 Apr 13 14:45 'Dog_Breed_KK_CV_Project2_Classification_Ver 4.ipynb'
# -rw------- 1 root root    148244 Feb 29  2020  Fashion_mnist_DL_HyperparameterTuning_2.ipynb
# -rw------- 1 root root    888070 Feb 15  2020 'FoundationsComputerVisionImageBasics (1).ipynb'
# -rw------- 1 root root  26574193 Sep  7 18:21  images_racoon.rar
# -rw------- 1 root root    108104 Feb  9  2020 'Introduction to NN_Project_ Resi_6_Solutions_KK_ver 5.ipynb'
# -rw------- 1 root root    511348 Apr  5 11:46 'KK_ Blog Authorship Corpus_V3.ipynb'
# -rw------- 1 root root    218954 Apr 12 14:23  labels.csv.zip
# -rw------- 1 root root    104428 Feb 15  2020  lena.jpg
# -rw------- 1 root root    594248 Mar 13  2020 'Neural_Networks_ Deep_Learning_SVHN_CNN_ Sol_KK_V4.ipynb'
# -rw------- 1 root root    463480 Mar  7  2020 'Neural Networks Project-2 _SVHN_CNN_Transfer_Sol_KK_ V2.ipynb'
# -rw------- 1 root root   1259426 Jun 21 17:23  NLP_Project_Sarcasm_Detection_Solution_KK.ipynb
# -rw------- 1 root root     14421 Feb 16  2020  PlantBreedClassification_using_TransferLearning_VGG16.ipynb
# -rw------- 1 root root  51667341 Jan 30  2020  prices.csv
# -rw------- 1 root root     59007 Jan 30  2020 'Questions - Internal - R6 AIML Labs  KK solutions.ipynb'
# -rw------- 1 root root    111080 Jun  1 02:40 'Questions - Internal - Sequential NLP Lab.ipynb'
# -rw------- 1 root root    518538 Mar  2  2020  R7_InternalLab_Sol_FMNIST_Simple_CNN_CIFAR_DATA_Augment_KK.ipynb
# -rw------- 1 root root      4462 Feb  2  2020  Recosys_Project_Residency6_Solutions_KK
# -rw------- 1 root root  14436440 Feb 16  2020  redlabel_cnn.h5
# drwx------ 2 root root      4096 Feb 15  2020 'residency 7 '
# -rw------- 1 root root    288160 Apr 12 14:23  sample_submission.csv.zip
# -rw------- 1 root root     55102 Mar 17 07:21  sentiment_analysis_twitter_data_questions.ipynb
# -rw------- 1 root root    309347 Feb 16  2020  SVHN_CNN_Transfer_Updated.ipynb
# -rw------- 1 root root 491644096 Feb 16  2020  SVHN_single_grey1.h5
# -rw------- 1 root root 362738853 Apr 12 14:23  test.zip
# -rw------- 1 root root      7913 Sep  7 18:20  train_labels.csv
# -rw------- 1 root root 361279070 Apr 12 14:23  train.zip
# -rw------- 1 root root   1260464 Mar 15 09:52  tweets.csv
# -rw------- 1 root root 186534864 Apr 12 15:34  vgg16_weights_full_model.h5
# -rw------- 1 root root  58889256 Apr 12 15:19  vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %% [markdown]
# ### Load the training data from train.csv file

# %%
df = pd.read_csv("train_labels.csv")

# %% [markdown]
# ### Print the shape of the train dataset

# %%
df.shape
# Out:
# (173, 8)

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE =128

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
import csv
with open('train_labels.csv','r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile) - 1, 4))
    spamreader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    next(spamreader, None)
    for i,row in enumerate(spamreader):
        #print(row)
        for j, r in enumerate(row): # Parse row with seven entities
            #print(i)
            if((j!= 0) & (j!=3)):
                row[j] = int(r)
            
        #print(row)      
        path, width, height, class_, xmin, ymin, xmax, ymax = row
        paths.append(path)
        #print(i)
        coords[i,0] = xmin * IMAGE_SIZE / width
        coords[i,1] = ymin * IMAGE_SIZE / height
        coords[i,2] = xmax * IMAGE_SIZE / width # Normalize bounding box by image size
        coords[i,3] = ymax * IMAGE_SIZE / height

# %%
# !pip install unrar
# !pip install rarfile
# Out:
# Requirement already satisfied: unrar in /usr/local/lib/python3.6/dist-packages (0.4)
# Requirement already satisfied: rarfile in /usr/local/lib/python3.6/dist-packages (4.0)

# %%
# !unrar x "//content/drive/My Drive/Colab Notebooks/images_racoon.rar"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from //content/drive/My Drive/Colab Notebooks/images_racoon.rar
#
# Creating    images                                                    OK
# Creating    images/images                                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
from PIL import Image
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, fil in enumerate(paths):
    print(i, fil)
    img = Image.open('/content/drive/My Drive/Colab Notebooks/images/' + fil)
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))
# Out:
# 0 raccoon-17.jpg
# 1 raccoon-11.jpg
# 2 raccoon-63.jpg
# 3 raccoon-63.jpg
# 4 raccoon-60.jpg
# 5 raccoon-69.jpg
# 6 raccoon-180.jpg
# 7 raccoon-200.jpg
# 8 raccoon-141.jpg
# 9 raccoon-19.jpg
# 10 raccoon-84.jpg
# 11 raccoon-124.jpg
# 12 raccoon-182.jpg
# 13 raccoon-111.jpg
# 14 raccoon-91.jpg
# 15 raccoon-79.jpg
# 16 raccoon-93.jpg
# 17 raccoon-20.jpg
# 18 raccoon-42.jpg
# 19 raccoon-139.jpg
# 20 raccoon-58.jpg
# 21 raccoon-71.jpg
# 22 raccoon-183.jpg
# 23 raccoon-1.jpg
# 24 raccoon-169.jpg
# 25 raccoon-82.jpg
# 26 raccoon-4.jpg
# 27 raccoon-101.jpg
# 28 raccoon-10.jpg
# 29 raccoon-166.jpg
# 30 raccoon-184.jpg
# 31 raccoon-38.jpg
# 32 raccoon-120.jpg
# 33 raccoon-142.jpg
# 34 raccoon-149.jpg
# 35 raccoon-51.jpg
# 36 raccoon-43.jpg
# 37 raccoon-123.jpg
# 38 raccoon-66.jpg
# 39 raccoon-9.jpg
# 40 raccoon-178.jpg
# 41 raccoon-47.jpg
# 42 raccoon-167.jpg
# 43 raccoon-54.jpg
# 44 raccoon-77.jpg
# 45 raccoon-155.jpg
# 46 raccoon-89.jpg
# 47 raccoon-153.jpg
# 48 raccoon-179.jpg
# 49 raccoon-115.jpg
# 50 raccoon-64.jpg
# 51 raccoon-56.jpg
# 52 raccoon-44.jpg
# 53 raccoon-39.jpg
# 54 raccoon-26.jpg
# 55 raccoon-162.jpg
# 56 raccoon-170.jpg
# 57 raccoon-187.jpg
# 58 raccoon-131.jpg
# 59 raccoon-174.jpg
# 60 raccoon-92.jpg
# 61 raccoon-193.jpg
# 62 raccoon-138.jpg
# 63 raccoon-157.jpg
# 64 raccoon-108.jpg
# 65 raccoon-116.jpg
# 66 raccoon-117.jpg
# 67 raccoon-117.jpg
# 68 raccoon-12.jpg
# 69 raccoon-12.jpg
# 70 raccoon-16.jpg
# 71 raccoon-90.jpg
# 72 raccoon-160.jpg
# 73 raccoon-75.jpg
# 74 raccoon-199.jpg
# 75 raccoon-97.jpg
# 76 raccoon-188.jpg
# 77 raccoon-21.jpg
# 78 raccoon-35.jpg
# 79 raccoon-85.jpg
# 80 raccoon-49.jpg
# 81 raccoon-86.jpg
# 82 raccoon-34.jpg
# 83 raccoon-196.jpg
# 84 raccoon-96.jpg
# 85 raccoon-3.jpg
# 86 raccoon-2.jpg
# 87 raccoon-52.jpg
# 88 raccoon-81.jpg
# 89 raccoon-112.jpg
# 90 raccoon-18.jpg
# 91 raccoon-94.jpg
# 92 raccoon-98.jpg
# 93 raccoon-83.jpg
# 94 raccoon-36.jpg
# 95 raccoon-24.jpg
# 96 raccoon-24.jpg
# 97 raccoon-195.jpg
# 98 raccoon-55.jpg
# 99 raccoon-55.jpg
# 100 raccoon-175.jpg
# 101 raccoon-163.jpg
# 102 raccoon-48.jpg
# 103 raccoon-70.jpg
# 104 raccoon-119.jpg
# 105 raccoon-119.jpg
# 106 raccoon-119.jpg
# 107 raccoon-88.jpg
# 108 raccoon-61.jpg
# 109 raccoon-61.jpg
# 110 raccoon-121.jpg
# 111 raccoon-74.jpg
# 112 raccoon-133.jpg
# 113 raccoon-177.jpg
# 114 raccoon-177.jpg
# 115 raccoon-159.jpg
# 116 raccoon-53.jpg
# 117 raccoon-132.jpg
# 118 raccoon-198.jpg
# 119 raccoon-198.jpg
# 120 raccoon-103.jpg
# 121 raccoon-46.jpg
# 122 raccoon-50.jpg
# 123 raccoon-37.jpg
# 124 raccoon-161.jpg
# 125 raccoon-194.jpg
# 126 raccoon-32.jpg
# 127 raccoon-15.jpg
# 128 raccoon-147.jpg
# 129 raccoon-151.jpg
# 130 raccoon-80.jpg
# 131 raccoon-6.jpg
# 132 raccoon-154.jpg
# 133 raccoon-135.jpg
# 134 raccoon-118.jpg
# 135 raccoon-150.jpg
# 136 raccoon-102.jpg
# 137 raccoon-130.jpg
# 138 raccoon-130.jpg
# 139 raccoon-7.jpg
# 140 raccoon-107.jpg
# 141 raccoon-173.jpg
# 142 raccoon-165.jpg
# 143 raccoon-25.jpg
# 144 raccoon-67.jpg
# 145 raccoon-13.jpg
# 146 raccoon-191.jpg
# 147 raccoon-45.jpg
# 148 raccoon-31.jpg
# 149 raccoon-31.jpg
# 150 raccoon-172.jpg
# 151 raccoon-100.jpg
# 152 raccoon-148.jpg
# 153 raccoon-148.jpg
# 154 raccoon-23.jpg
# 155 raccoon-30.jpg
# 156 raccoon-33.jpg
# 157 raccoon-136.jpg
# 158 raccoon-114.jpg
# 159 raccoon-76.jpg
# 160 raccoon-104.jpg
# 161 raccoon-109.jpg
# 162 raccoon-87.jpg
# 163 raccoon-113.jpg
# 164 raccoon-78.jpg
# 165 raccoon-65.jpg
# 166 raccoon-122.jpg
# 167 raccoon-73.jpg
# 168 raccoon-137.jpg
# 169 raccoon-171.jpg
# 170 raccoon-190.jpg
# 171 raccoon-22.jpg
# 172 raccoon-152.jpg

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
import pandas as pd
import numpy as np
import cv2
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.layers import Conv2D, Reshape
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
from tensorflow.keras.models import Model
model = MobileNet(input_shape=(128, 128, 3), include_top=False) 
for layer in model.layers:
    layer.trainable = False
model1 = model.layers[-1].output
model1 = Conv2D(4, kernel_size=4)(model1)
model1 = Reshape((4,))(model1)

myModel = Model(inputs=model.input,outputs = model1)

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.compat.v1.py_func(loss, [y_true, y_pred], tf.float32)
    return iou

# %%
model.summary()
# Out:
# Model: "mobilenet_1.00_128"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 129, 129, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 64, 64, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 64, 64, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 64, 64, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 64, 64, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 64, 64, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 64, 64, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 64, 64, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 65, 65, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 32, 32, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 32, 32, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 32, 32, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 32, 32, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 33, 33, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 16, 16, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 16, 16, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 16, 16, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 17, 17, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 8, 8, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 9, 9, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 4, 4, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 4, 4, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 4, 4, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# =================================================================
# Total params: 3,228,864
# Trainable params: 0
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
tf.compat.v1.py_func
# Out:
# <function tensorflow.python.ops.script_ops.py_func>

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
myModel.compile(loss="mean_squared_error", optimizer="Adam", metrics=IoU)
myModel.fit(batch_images, coords, epochs=30,
                    batch_size = 32,                                      
                    workers=7,
                    use_multiprocessing=True,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From <ipython-input-124-7ee04dc8b169>:25: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# 6/6 [==============================] - 2s 299ms/step - loss: 3996.0129 - IoU: 0.0855
# Epoch 2/30
# 6/6 [==============================] - 2s 298ms/step - loss: 739.4187 - IoU: 0.4352
# Epoch 3/30
# 6/6 [==============================] - 2s 297ms/step - loss: 449.2657 - IoU: 0.5888
# Epoch 4/30
# 6/6 [==============================] - 2s 295ms/step - loss: 605.6675 - IoU: 0.5408
# Epoch 5/30
# 6/6 [==============================] - 2s 296ms/step - loss: 347.6496 - IoU: 0.6346
# Epoch 6/30
# 6/6 [==============================] - 2s 295ms/step - loss: 192.2901 - IoU: 0.6661
# Epoch 7/30
# 6/6 [==============================] - 2s 294ms/step - loss: 202.1818 - IoU: 0.6555
# Epoch 8/30
# 6/6 [==============================] - 2s 293ms/step - loss: 159.4919 - IoU: 0.7069
# Epoch 9/30
# 6/6 [==============================] - 2s 296ms/step - loss: 122.9735 - IoU: 0.7441
# Epoch 10/30
# 6/6 [==============================] - 2s 299ms/step - loss: 115.5192 - IoU: 0.7680
# Epoch 11/30
# 6/6 [==============================] - 2s 297ms/step - loss: 101.4060 - IoU: 0.7754
# Epoch 12/30
# 6/6 [==============================] - 2s 293ms/step - loss: 85.9804 - IoU: 0.7915
# Epoch 14/30
# 6/6 [==============================] - 2s 302ms/step - loss: 79.5013 - IoU: 0.8008
# Epoch 15/30
# 6/6 [==============================] - 2s 294ms/step - loss: 75.0110 - IoU: 0.8166
# Epoch 16/30
# 6/6 [==============================] - 2s 292ms/step - loss: 71.0854 - IoU: 0.8136
# Epoch 17/30
# 6/6 [==============================] - 2s 292ms/step - loss: 69.7384 - IoU: 0.8132
# Epoch 18/30
# 6/6 [==============================] - 2s 298ms/step - loss: 67.9770 - IoU: 0.8213
# Epoch 19/30
# 6/6 [==============================] - 2s 295ms/step - loss: 64.1755 - IoU: 0.8303
# Epoch 20/30
# 6/6 [==============================] - 2s 311ms/step - loss: 60.3560 - IoU: 0.8415
# Epoch 21/30
# 6/6 [==============================] - 2s 293ms/step - loss: 60.9983 - IoU: 0.8262
# Epoch 22/30
# 6/6 [==============================] - 2s 295ms/step - loss: 60.9607 - IoU: 0.8238
# Epoch 23/30
# 6/6 [==============================] - 2s 299ms/step - loss: 58.3246 - IoU: 0.8327
# Epoch 24/30
# 6/6 [==============================] - 2s 297ms/step - loss: 58.4191 - IoU: 0.8395
# Epoch 25/30
# 6/6 [==============================] - 2s 293ms/step - loss: 57.7844 - IoU: 0.8359
# Epoch 26/30
# 6/6 [==============================] - 2s 291ms/step - loss: 55.3990 - IoU: 0.8489
# Epoch 27/30
# 6/6 [==============================] - 2s 294ms/step - loss: 56.6983 - IoU: 0.8385
# Epoch 28/30
# 6/6 [==============================] - 2s 297ms/step - loss: 55.1176 - IoU: 0.8614
# Epoch 29/30
# 6/6 [==============================] - 2s 294ms/step - loss: 53.3632 - IoU: 0.8622
# Epoch 30/30
# 6/6 [==============================] - 2s 292ms/step - loss: 50.6594 - IoU: 0.8682

# %% [markdown]
# ### Pick a test image from the given data

# %%
test_img = '/content/drive/My Drive/Colab Notebooks/images/raccoon-26.jpg'
unscaled = cv2.imread(test_img)

# %%
print(unscaled. shape )
# Out:
# (374, 306, 3)
# (374, 306, 3)

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
img_ht , img_wd, chnl = unscaled.shape
image = cv2.resize(unscaled,(IMAGE_SIZE,IMAGE_SIZE))
feat_scaled = preprocess_input(np.array(image,dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = myModel.predict(x=np.array([feat_scaled]))[0]

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * img_wd / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * img_ht / IMAGE_SIZE)

x1 = int((region[2]) * img_wd / IMAGE_SIZE)
y1 = int((region[3]) * img_ht / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
